# %%
import pandas as pd

# %% [markdown]
# ### Metadata of airbnb data of New York listings

# %%
nyc_df=pd.read_csv('/Users/maverick/Documents/Capital One/nyc_df.csv')
nyc_df.info(verbose=all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48755 entries, 0 to 48754
# Data columns (total 34 columns):
# id                              48755 non-null int64
# street                          48755 non-null object
# neighbourhood                   48743 non-null object
# neighbourhood_cleansed          48755 non-null object
# neighbourhood_group_cleansed    48755 non-null object
# city                            48693 non-null object
# state                           48749 non-null object
# zipcode                         48755 non-null float64
# market                          48755 non-null object
# smart_location                  48755 non-null object
# latitude                        48755 non-null float64
# longitude                       48755 non-null float64
# is_location_exact               48755 non-null object
# property_type                   48755 non-null object
# room_type                       48755 non-null object
# ...

# %%
nyc_df.head(5)
# Out:
#      id                        street neighbourhood neighbourhood_cleansed  \
# 0  2539  Brooklyn , NY, United States      Brooklyn             Kensington
# 1  2595   New York, NY, United States     Manhattan                Midtown
# 2  3647   New York, NY, United States        Harlem                 Harlem
# 3  3831   Brooklyn, NY, United States      Brooklyn           Clinton Hill
# 4  5022   New York, NY, United States   East Harlem            East Harlem
#
#   neighbourhood_group_cleansed       city state  zipcode    market  \
# 0                     Brooklyn  Brooklyn     NY  11218.0  New York
# 1                    Manhattan   New York    NY  10018.0  New York
# 2                    Manhattan   New York    NY  10027.0  New York
# 3                     Brooklyn   Brooklyn    NY  11238.0  New York
# 4                    Manhattan   New York    NY  10029.0  New York
#
#   smart_location  ...  number_of_reviews  first_review last_review  \
# ...

# %% [markdown]
# ### Metadata of Zillow Cost data of zipcodes present in airbnb data

# %%
zillow_nyc=pd.read_csv('zillow_nyc.csv')
zillow_nyc.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 262 columns):
# RegionID      float64
# RegionName    int64
# City          object
# State         object
# Metro         object
# CountyName    object
# SizeRank      float64
# 1996-04       float64
# 1996-05       float64
# 1996-06       float64
# 1996-07       float64
# 1996-08       float64
# 1996-09       float64
# 1996-10       float64
# 1996-11       float64
# 1996-12       float64
# 1997-01       float64
# 1997-02       float64
# 1997-03       float64
# 1997-04       float64
# 1997-05       float64
# 1997-06       float64
# 1997-07       float64
# 1997-08       float64
# 1997-09       float64
# 1997-10       float64
# 1997-11       float64
# 1997-12       float64
# 1998-01       float64
# 1998-02       float64
# 1998-03       float64
# 1998-04       float64
# 1998-05       float64
# 1998-06       float64
# 1998-07       float64
# 1998-08       float64
# 1998-09       float64
# ...

# %%
zillow_nyc.head(5)
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0   61639.0       10025  New York    NY  New York   New York       1.0
# 1   61637.0       10023  New York    NY  New York   New York       3.0
# 2   61703.0       10128  New York    NY  New York   New York      14.0
# 3   61625.0       10011  New York    NY  New York   New York      15.0
# 4   61617.0       10003  New York    NY  New York   New York      21.0
#
#    1996-04  1996-05  1996-06  ...    2016-09    2016-10    2016-11    2016-12  \
# 0      NaN      NaN      NaN  ...  1374400.0  1364100.0  1366300.0  1354800.0
# 1      NaN      NaN      NaN  ...  1993500.0  1980700.0  1960900.0  1951300.0
# 2      NaN      NaN      NaN  ...  1526000.0  1523700.0  1527200.0  1541600.0
# 3      NaN      NaN      NaN  ...  2354000.0  2355500.0  2352200.0  2332100.0
# 4      NaN      NaN      NaN  ...  1932800.0  1930400.0  1937500.0  1935100.0
#
#      2017-01    2017-02    2017-03    2017-04    2017-05    2017-06
# ...

# %% [markdown]
# ### Metadata of median price per year of all zipcodes present in nyc_zillow_df data

# %%
zillow_df_year=pd.read_csv('zillow_df_year.csv')
zillow_df_year.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 33 columns):
# date_year    9 non-null int64
# 10025        9 non-null int64
# 10023        9 non-null int64
# 10128        9 non-null int64
# 10011        9 non-null int64
# 10003        9 non-null int64
# 11201        9 non-null int64
# 11234        9 non-null int64
# 10314        9 non-null int64
# 11215        9 non-null int64
# 10028        9 non-null int64
# 7093         9 non-null int64
# 10021        9 non-null int64
# 7302         9 non-null int64
# 10014        9 non-null int64
# 10036        9 non-null int64
# 11434        9 non-null int64
# 10306        9 non-null int64
# 10312        9 non-null int64
# 91766        9 non-null int64
# 10022        9 non-null int64
# 11217        9 non-null int64
# 10013        9 non-null int64
# 11231        9 non-null int64
# 10304        9 non-null int64
# 10705        9 non-null int64
# 10305        9 non-null int64
# ...

# %%
zillow_df_year.head(5)
# Out:
#    date_year    10025    10023    10128    10011    10003   11201   11234  \
# 0       2009   854500  1374950   987550  1508800  1396050  696300  370600
# 1       2010   859050  1344550  1009050  1446300  1278700  765950  390600
# 2       2011   898600  1379700   982150  1435900  1363050  796650  375050
# 3       2012   915050  1380450  1056000  1542250  1370400  838000  366950
# 4       2013  1045000  1496400  1168400  1798350  1533100  923350  374350
#
#     10314   11215  ...   11231   10304   10705   10305   10704   11003  \
# 0  286550  516850  ...  572650  272350  352500  328350  355750  280650
# 1  287100  545700  ...  597400  260750  330500  321300  348050  277400
# 2  275200  605250  ...  649250  248150  332450  305150  332500  267050
# 3  268600  618500  ...  669900  233250  303050  300250  310800  259400
# 4  274300  715350  ...  765900  237400  310850  301850  311200  262550
#
#     10309   10308   94085   10303
# 0  311800  317600  410600  261350
# ...

# %% [markdown]
# ### Metadata of Airbnb data with median cost for that zipcode

# %%
Airbnb_Median_Cost=pd.read_csv('Airbnb_Median_Cost.csv')
Airbnb_Median_Cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1570 entries, 0 to 1569
# Data columns (total 35 columns):
# id                              1570 non-null int64
# street                          1570 non-null object
# neighbourhood                   1570 non-null object
# neighbourhood_cleansed          1570 non-null object
# neighbourhood_group_cleansed    1570 non-null object
# city                            1567 non-null object
# state                           1569 non-null object
# zipcode                         1570 non-null float64
# market                          1570 non-null object
# smart_location                  1570 non-null object
# latitude                        1570 non-null float64
# longitude                       1570 non-null float64
# is_location_exact               1570 non-null object
# property_type                   1570 non-null object
# room_type                       1570 non-null object
# accommodates                    1570 non-null int64
# ...

# %%
Airbnb_Median_Cost.head(5)
# Out:
#       id                       street    neighbourhood neighbourhood_cleansed  \
# 0  16458  Brooklyn, NY, United States         Brooklyn             Park Slope
# 1  20853  Brooklyn, NY, United States         Brooklyn       Prospect Heights
# 2  23135  Brooklyn, NY, United States  Carroll Gardens        Carroll Gardens
# 3  27006  New York, NY, United States        Manhattan        Upper West Side
# 4  27659  Brooklyn, NY, United States         Brooklyn            South Slope
#
#   neighbourhood_group_cleansed      city state  zipcode    market  \
# 0                     Brooklyn  Brooklyn    NY  11215.0  New York
# 1                     Brooklyn  Brooklyn    NY  11217.0  New York
# 2                     Brooklyn  Brooklyn    NY  11231.0  New York
# 3                    Manhattan  New York    NY  10023.0  New York
# 4                     Brooklyn  Brooklyn    NY  11215.0  New York
#
#   smart_location  ...  first_review  last_review review_scores_rating  \
# ...
